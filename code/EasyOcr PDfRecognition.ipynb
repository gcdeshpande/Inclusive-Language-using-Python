# %%
from pdf2image import convert_from_path
import numpy as np
import PIL
from PIL import ImageDraw
import spacy
import IPython

# %%
images = convert_from_path(r"C:\Users\divek\Desktop\functionalSample.pdf",poppler_path = r"C:\Program Files\poppler-0.68.0_x86\bin")

# %%
from IPython.display import display, Image
display(images[0])
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200>

# %%
bounds = reader.readtext(np.array(images[0])
# Out:
#   File "<ipython-input-94-d877a26ece57>", line 1
#     bounds = reader.readtext(np.array(images[0])
#                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
def draw_boundedbox(image, bounds, color='blue', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boundedbox(images[0],bounds)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200>

# %%
bounds[1][1]
# Out:
# 'John W_'

# %%
text=''
for i in range(len(bounds)):
    text = text + bounds[i][1] + '\n'
    
print(text)
# Out:
# Functional Resume Sample
# John W_
# Smith
# 2002 Front Range
# Fort Collins, CO 80525
# iwsmith@colostate_edu
# Career Summary
# Four years experience in early childhood development with a diverse background in the care of
# needs children and adults.
# Adult Care Experience
# Determined work placement for 150
# needs adult clients.
# Maintained client databases and records.
# Coordinated client contact with local health care professionals o a monthly basis.
# Managed 25 volunteer workers.
# Childcare Experience
# Coordinated service assignments for 20 part-time counselors and 100 client families
# Oversaw daily activity and outing planning for 100 clients.
# Assisted families of special needs clients with researching financial assistance and
# healthcare_
# Assisted teachers with managing daily classroom activities.
# Oversaw daily and special student activities
# Employment History
# 1999-2002
# Counseling Supervisor; The Wesley Center, Little Rock Arkansas.
# 1997-1999
# ...

# %%
nlp=spacy.load('en_core_web_sm')
doc=nlp(text)
doc
# Out:
# Functional Resume Sample
# John W_
# Smith
# 2002 Front Range
# Fort Collins, CO 80525
# iwsmith@colostate_edu
# Career Summary
# Four years experience in early childhood development with a diverse background in the care of
# needs children and adults.
# Adult Care Experience
# Determined work placement for 150
# needs adult clients.
# Maintained client databases and records.
# Coordinated client contact with local health care professionals o a monthly basis.
# Managed 25 volunteer workers.
# Childcare Experience
# Coordinated service assignments for 20 part-time counselors and 100 client families
# Oversaw daily activity and outing planning for 100 clients.
# Assisted families of special needs clients with researching financial assistance and
# healthcare_
# Assisted teachers with managing daily classroom activities.
# Oversaw daily and special student activities
# Employment History
# 1999-2002
# Counseling Supervisor; The Wesley Center, Little Rock Arkansas.
# 1997-1999
# ...

# %%
for token in doc:
    print(token.text(1)
# Out:
# Functional
# Resume
# Sample
#
#
# John
# W
# _
#
#
# Smith
#
#
# 2002
# Front
# Range
#
#
# Fort
# Collins
# ,
# CO
# 80525
#
#
# iwsmith@colostate_edu
#
#
# Career
# Summary
#
#
# Four
# years
# experience
# in
# early
# childhood
# development
# with
# a
# diverse
# background
# in
# the
# care
# of
#
#
# needs
# children
# and
# adults
# .
#
#
# Adult
# Care
# Experience
#
#
# Determined
# work
# placement
# for
# 150
#
#
# needs
# adult
# clients
# .
#
#
# Maintained
# client
# databases
# and
# records
# .
#
#
# Coordinated
# client
# contact
# with
# local
# health
# care
# professionals
# o
# a
# monthly
# basis
# .
#
#
# Managed
# 25
# volunteer
# workers
# .
#
#
# Childcare
# Experience
#
#
# Coordinated
# service
# assignments
# for
# 20
# part
# -
# time
# counselors
# and
# 100
# client
# families
#
#
# Oversaw
# daily
# activity
# and
# outing
# planning
# for
# 100
# clients
# .
#
#
# Assisted
# families
# of
# special
# needs
# clients
# with
# researching
# ...
